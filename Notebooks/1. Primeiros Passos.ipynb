# %% [markdown]
# # 1. Primeiros passos

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
print("Olá, meu nome é Joana!")
print("Você tem 27 anos!")
print("Seu peso é 59 kg!")
# Out:
# Olá, meu nome é Joana!
# Você tem 27 anos!
# Seu peso é 59 kg!

# %%
nome = "Joana"
idade = 27
peso = 59

# 3 formas de print (impressão)
print("Olá {}!".format(nome))
print("Você tem",idade,"anos!")
print(f"Seu peso é {peso} kg!")
# Out:
# Olá Joana!
# Você tem 27 anos!
# Seu peso é 59 kg!
