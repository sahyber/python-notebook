# %% [markdown]
# # 2. Variáveis
#
# * Declarando variáveis

# %%
nome = "Eric" # String
idade = 18 # int
peso = 60.3 # float

# %%
type(nome)
# Out:
# str

# %%
type(idade)
# Out:
# int

# %%
type(peso)
# Out:
# float

# %% [markdown]
# * Substituição de Dados

# %%
x = 4
x = 6
print(x)
# Out:
# 6

# %%
nome = input()
print(nome)
# Out:
# Tiago

# %%
nome = input("Digite seu nome: ")
idade = input("Digite sua idade: ")
peso = input("Digite seu peso em kg: ")

# 3 formas de print (impressão)
print("Olá {}!".format(nome))
print("Você tem",idade,"anos!")
print(f"Seu peso é {peso} kg!")
# Out:
# Olá Andressa!
# Você tem 36 anos!
# Seu peso é 54 kg!

# %% [markdown]
# * OBS: os dados obtidos pelos input são Strings:

# %%
type(peso)
# Out:
# str

# %%
peso+peso
# Out:
# '5454'

# %%
# ERRO
peso/2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 2
#       1 # ERRO
# ----> 2 peso/2
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'

# %% [markdown]
# * Declarando múltiplos valores em uma única linha

# %%
x, y = 10, 20
print(x, y)
# Out:
# 10 20

# %% [markdown]
# * Declarando um valor para múltiplas variáveis

# %%
x = y = z = 10
print(x, y, z)
# Out:
# 10 10 10
